# %%
import pandas as pd
from database.DBConnector import *

# %% [markdown]
# #### SQL Connection

# %%
# t_execute_query("""
# SELECT *
# FROM dimarticle;
# """)

# %% [markdown]
# #### LLM check

# %% [markdown]
# ##### Init

# %%
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(
    openai_api_base="http://127.0.0.1:1234/v1",
    # openai_api_key="not-needed",  # LM Studio не потребує справжнього ключа
    # model_name="deepseek-r1-distill-llama-8b",     # Зазвичай це "gpt-3.5-turbo", але можеш поставити будь-що — це ігнорується
)
# Out:
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_30596\2181775281.py:3: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(

# %% [markdown]
# ##### Test message

# %%
res = llm.invoke('Hello!')
res
# Out:
# AIMessage(content="Hello there! How's your day going so far? 😊 \n\nWhat can I do for you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 11, 'total_tokens': 34, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': 'gemma-3-1b-it', 'finish_reason': 'stop', 'logprobs': None}, id='run-410b3bdb-cbb2-4866-95f6-2cb39f614c7c-0')

# %%
res.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hello there! How's your day going so far? 😊
#
# What can I do for you today?
