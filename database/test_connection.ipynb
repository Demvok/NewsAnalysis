# %%
import pandas as pd
from DBConnector import *

# %%
t_execute_query("""
SELECT *
FROM dimarticle;
""")

# %%
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(
    openai_api_base="http://127.0.0.1:1234/v1",
    # openai_api_key="not-needed",  # LM Studio не потребує справжнього ключа
    # model_name="deepseek-r1-distill-llama-8b",     # Зазвичай це "gpt-3.5-turbo", але можеш поставити будь-що — це ігнорується
)

# %%
llm.invoke('Hello!')
# Out:
# AIMessage(content='<think>\n\n</think>\n\nHello! How can I assist you today? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 5, 'total_tokens': 19, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': 'deepseek-r1-distill-llama-8b', 'finish_reason': 'stop', 'logprobs': None}, id='run-ae421f6c-f51e-4496-aa76-53f6cf28159b-0')
